# %% [markdown]
# # Manifesto TPC7
#
# ## Algoritmos
#
# * Título: Construir uma aplicação para manipular polinómios
# * Data de início: 2023-10-24
# * Data de fim: 2023-10-31
# * Supervisor:José Carlos Leite Ramalho, jcr@di.uminho.pt
# * Autor: Marta Cristina Nunes Silva A92041
# * Resumo: Este trabalho tem como objetivo construir uma aplicação para manipular polinómios.
# * Aquecimento: Instancia os seguintes exemplos num ficheiro de texto com o formato definido na última aula
#     - `x^7 - 3.7x^4 + 5x^3 - 88`
#     - `2x^2 + 17`
#     - `7x^4 + 6x^3 - x^2 + 43`
#     - `x^4`
#     - `x^2`
#     - `x^3`
#
# * Desenvolve as seguintes funcionalidades que não foram trabalhadas na aula:
#     1. Define uma função que dado um polinómio calcula a sua derivada;
#     2. Define uma função que recebe dois polinómios `p1` e `p2` e calcula um novo polinómio correspondente à soma de `p1` e `p2`;
#     3. Define uma função que recebe um polinómio e o desenha num gráfico.
#
# * Num ficheiro Python, cria uma aplicação para manipular polinómios com as seguintes operações:
#     1. Criar um polinómio interativamente;
#     2. Ler uma lista de polinómios de um ficheiro;
#     3. Listar polinómios: mostra numa tabela os polinómios carregados em memória, adicionando um número de ordem a cada um;
#     4. Calcular o valor de um polinómio num ponto (usa o número de ordem para referenciar o polinómio);
#     5. Listar polinómios com grau: à listagem anterior, acrescenta mais uma coluna com o grau;
#     6. Maior grau: mostra o polinómio de maior grau e indica o seu número de ordem;
#     7. Derivada: mostra uma tabela com os polinómios e as respetivas derivadas;
#     8. Somar dois polinómios: indicando os seus números de ordem;
#     9. Gerar um gráfico para o polinómio;
#     10. Gravar num ficheiro os polinómios em memória;
#     0. Sair da aplicação

# %%
def menu():
    print(""""App Polinómio"
(1) Criar polinómio;
(2) Calcular polinómio;
(3) Calcular tabela;
(4) Calcular a derivada do polinómio
(5) Listar polinomios com grau
(6) Polinomio de maior grau
(7) Somar dois polinomios
(8) Gerar gráfico de um polinomio
(9) Gravar polinomios em arquivo
...
(0) sair""")

from random import randint
import matplotlib.pyplot as plt

def criarTermo(c, e):  # construtor de tuplos
    return (c, e)
    
def criarPolinomio(): #criar polinomio vazio
    n=int(input("Número de termos do polinómio:"))
    p=[]
    i=0
    while i<n:
        r=coef, '*x**', exp
        p.append(r)
        i=i+1
    return p

def inserirTermo():
    p=criarPolinomio()
    t=int(input("Número de termos:"))
    for i in range(t):
        c = randint(0,100)
        e = randint (0,100)
        p.append((c,e))
    return p

def verTermo(t):
    (c, e) = t
    if e == 0:              #se o expoente for zero
        return str(c)
    else:
        return (str(c)+ 'x^'+ str(e))
    
def verPolinomio():
    p=inserirTermo()
    res = ""
    for i in p:        #percorrer uma lista por valor
        if res == "":  # se res for vazio
            res = verTermo(i)
        else:
            res= res + " + " + verTermo(i)
    print(res)


def calcPol():
    p=verPolinomio()
    m=input("Qual é o valor de x para o qual deseja calcular o y?")
    res = 0
    for (c,e) in p:
        res = res + c * x ** e
    return res

def tabela(p, nlinhas):
    for i in range(nlinhas):
        print(str(i) + "::" + str(calcPol(p,i)))

def chaveOrd(t):
    c,e = t # em vez de c podíamos meter _,e
    return e
def ordenarPol(p):
    p.sort(reverse=True, key=chaveOrd)            
    
def derivarPol(p):           
    res = []
    for (c,e) in p:
        if e > 0:
            res.append((c*e, e-1))
    return res    

def somar_polinomios(p1, p2):
    def polinomio_soma(x):
        return p1(x) + p2(x)
    return polinomio_soma

def listar_polinomios_com_grau(p):
    for i, polinomio in enumerate(p):
        grau = len(p.c) - 1
        print(f"{i + 1}: {p.c} (Grau {grau})")
        
def maior_grau(p):
    graus = [len(p.c) - 1 for pol in polinomios]
    max_grau = max(graus)
    index = graus.index(max_grau)
    print(f"O polinómio de maior grau é o {index + 1} com grau {max_grau}")


def desenhar_grafico_polinomio(p, intervalo=(-10, 10), pontos=100):
    x_valores = [intervalo[0] + i * (intervalo[1] - intervalo[0]) / (pontos - 1) for i in range(pontos)]
    y_valores = [polinomio(x) for x in x_valores]
    plt.plot(x_valores, y_valores)
    plt.xlabel("x")
    plt.ylabel("f(x)")
    plt.title("Gráfico do Polinómio")
    plt.grid(True)
    plt.show()


exemplos = [
    "x^7 - 3.7x^4 + 5x^3 - 88",
    "2x^2 + 17",
    "7x^4 + 6x^3 - x^2 + 43",
    "x^4",
    "x^2",
    "x^3"
]


polinomios = criarPolinomio(exemplos)


p1 = polinomios[0]
p2 = polinomios[1]

derivada = derivarPol(p1)
polinomio_soma = somar_polinomios(p1, p2)

desenhar_grafico_polinomio(p1)

op = "1" 
while op != "0":  
    menu()
    op=input("Qual é a sua opção?")
    if op == "1":
        print(verPolinomio())
    elif op == "2":
        lis = calcPol()
        print(lis)
    elif op == "3":
        print(lis(2))
    elif opcao == "4":
        print(derivarPol(p))
    elif opcao == "5":
        print(listar_polinomios_com_grau(p))
    elif opcao == "6":
        print(maior_grau(p))
    elif opcao == "7":
        ordem1 = int(input("Número de ordem do primeiro polinómio: "))
        ordem2 = int(input("Número de ordem do segundo polinómio: "))
        print(somar_dois_polinomios(p, ordem1, ordem2))
    elif opcao == "8":
        numero_ordem = int(input("Número de ordem do polinómio: "))
        gerar_grafico_polinomio(p[numero_ordem - 1])
    elif opcao == "9":
            arquivo = input("Nome do arquivo: ")
            salvar_polinomios_em_arquivo(p, arquivo)
    elif op == "0":
        print("Até à próxima...")
    else:
        print("Opção inválida!")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 121
#     108     plt.show()
#     111 exemplos = [
#     112     "x^7 - 3.7x^4 + 5x^3 - 88",
#     113     "2x^2 + 17",
#    (...)
#     117     "x^3"
#     118 ]
# --> 121 polinomios = criarPolinomio(exemplos)
#     124 p1 = polinomios[0]
#     125 p2 = polinomios[1]
#
# TypeError: criarPolinomio() takes 0 positional arguments but 1 was given
